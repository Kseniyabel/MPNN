# %%
# 7 классов препаратов:
# ингибиторы АПФ, блокаторы рецепторов к ангиотензину 2, бета-блокаторы,
# барбитураты, гистаминовые блокаторы, бензодиазепины,
# блокаторы кальциевых каналов производные дигидроперидина.

# %%
import os
import numpy as np
import pandas as pd
import ast
from collections import Counter
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.1

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Flatten, Convolution2D, BatchNormalization
from tensorflow.keras.layers import ReLU, MaxPool2D, AvgPool2D, GlobalAvgPool2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

# %%
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Draw import MolsToGridImage
import threading
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# Данные получены при помощи Drug Bank https://go.drugbank.com/releases/latest
#
# Из общей базы данных выбраны только малые молекулы.
#
# Описание колонок:
# drugname - название препарата, drug_type - тип - малая молекула, groups - препарат подтвежденный или исследуемый, codes -  содержит в себе все кодировки по АТХ (все 4 уровня, все возможниые варианты), относящиеся с этому препарату, smiles - SMILES, atc_4 - добавленная для наглядности колонка, содержит один из вариантов АТХ классификации 4го уровня, подходящия для препарата.

# %%
# Считаем датасет.

df_sm = pd.read_csv('new_data_db')

df_sm.head()
# Out:
#        drugname       drug_type                           groups  \
# 0   Bivalirudin  small molecule  ['approved', 'investigational']
# 1    Leuprolide  small molecule  ['approved', 'investigational']
# 2     Goserelin  small molecule                     ['approved']
# 3  Gramicidin D  small molecule                     ['approved']
# 4  Desmopressin  small molecule                     ['approved']
#
#                                                codes  \
# 0  ['Direct thrombin inhibitors', 'ANTITHROMBOTIC...
# 1  ['Gonadotropin releasing hormone analogues', '...
# 2  ['Gonadotropin releasing hormone analogues', '...
# 3  ['Antibiotics', 'THROAT PREPARATIONS', 'THROAT...
# 4  ['Vasopressin and analogues', 'POSTERIOR PITUI...
#
#                                               smiles  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# 1  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=...
# 2  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 3  CC(C)C[C@@H](NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(...
# 4  NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...
#
#                                       atc_4
# 0                Direct thrombin inhibitors
# 1  Gonadotropin releasing hormone analogues
# 2  Gonadotropin releasing hormone analogues
# 3                               Antibiotics
# 4                 Vasopressin and analogues

# %%
# Размер всего датасета.

df_sm.shape
# Out:
# (12227, 6)

# %%
# У многих препаратов отсутствует кодировка по ATC.
# Часто такие препараты не содержат описания, описания мишеней действия.

df_sm[df_sm['codes']=='[]'].shape
# Out:
# (9203, 6)

# %% [markdown]
# Анатомо-терапевтическо-химическая классификация (АТХ, ATC) — международная система классификации лекарственных средств, которая ведется ВОЗ и широко используется во многих странах для изучения обращения ЛС. Состоит из 5 уровней.
# https://www.whocc.no/
#
# 1-й уровень, первый знак (латинская прописная буква) указывает на анатомическую область, заболевания органов которой служат показаниями к применению препаратов конкретного действующего вещества, — основная анатомическая группа;
#
# 2-й уровень, второй и третий знаки (арабские цифры) — основная терапевтическая группа;
#
# 3-й уровень, четвертый знак (латинская прописная буква) — терапевтическая подгруппа;
#
# 4-й уровень, пятый знак (латинская прописная буква) — терапевтическо-химическая группа;
#
# 5-й уровень, шестой и седьмой знаки (арабские цифры) — наименование действующего вещества или их комбинации.
#
# Для разделения на классы будет использован 4 уровень классификации, так как он учитывает химические особенности молекулы и мишень, на которую она действует.

# %%
# Посчитаем, сколько препаратов с различными кодировками ATC_4 есть всего.
# У некоторых препаратов могут быть 2 ATC кодировки, с одинаковыми ATC_4.

atc_4_list = []

for i in df_sm['codes']:
    for j in ast.literal_eval(i):
        if j[-1].islower():
            atc_4_list.append(j)

# %%
atc_4_series = pd.Series(atc_4_list)

pd.set_option('display.max_rows', None)

atc_4_series.value_counts()
# Out:
# Sulfonamides                                                                                       75
# Antibiotics                                                                                        73
# Antivirals for treatment of HIV infections, combinations                                           71
# Progestogens and estrogens, fixed combinations                                                     68
# Combinations of oral blood glucose lowering drugs                                                  54
# Combinations for eradication of Helicobacter pylori                                                49
# Lipid modifying agents in combination with other drugs                                             44
# Progestogens and estrogens, sequential preparations                                                42
# Benzodiazepine derivatives                                                                         40
# Corticosteroids                                                                                    35
# Imidazole derivatives                                                                              34
# Antivirals for treatment of HCV infections                                                         33
# Selective beta-2-adrenoreceptor agonists                                                           33
# Antiinfectives                                                                                     33
# Fluoroquinolones                                                                                   31
# Other antihistamines for systemic use                                                              29
# Tetracyclines                                                                                      29
# Antiinflammatory preparations, non-steroids for topical use                                        28
# Adrenergics in combination with anticholinergics incl. triple combinations with corticosteroids    28
# Antidotes                                                                                          27
# Combinations of antibacterials                                                                     27
# Adrenergic and dopaminergic agents                                                                 27
# Other antineoplastic agents                                                                        27
# Combinations of penicillins, incl. beta-lactamase inhibitors                                       27
# Other cough suppressants                                                                           26
# Other antidepressants                                                                              26
# Glucocorticoids                                                                                    25
# Propionic acid derivatives                                                                         24
# Adrenergics in combination with corticosteroids or other drugs, excl. anticholinergics             24
# Xanthines                                                                                          24
# Corticosteroids and antiinfectives in combination                                                  23
# Other antifungals for topical use                                                                  23
# Platelet aggregation inhibitors excl. heparin                                                      23
# Salicylic acid and derivatives                                                                     23
# Combinations of drugs for treatment of tuberculosis                                                22
# Other dermatologicals                                                                              22
# Other vasodilators used in cardiac diseases                                                        22
# Opioids in combination with non-opioid analgesics                                                  22
# Other antiepileptics                                                                               21
# Imidazole and triazole derivatives                                                                 21
# Combinations of various lipid modifying agents                                                     21
# Bisphosphonates, combinations                                                                      21
# Other protein kinase inhibitors                                                                    21
# Synthetic anticholinergics, quaternary ammonium compounds                                          21
# Non-selective monoamine reuptake inhibitors                                                        21
# Barbiturates, plain                                                                                20
# Artemisinin and derivatives, combinations                                                          20
# Penicillins with extended spectrum                                                                 20
# Selective immunosuppressants                                                                       20
# Dihydropyridine derivatives                                                                        20
# Various alimentary tract and metabolism products                                                   19
# Antiinfectives and antiseptics for local oral treatment                                            19
# Acetic acid derivatives and related substances                                                     19
# Other psychostimulants and nootropics                                                              19
# Third-generation cephalosporins                                                                    18
# Thiazides and potassium in combination                                                             18
# Amides                                                                                             18
# Angiotensin II receptor blockers (ARBs), other combinations                                        18
# Antivirals                                                                                         18
# Natural opium alkaloids                                                                            17
# Antiseptics                                                                                        17
# Alpha-adrenoreceptor antagonists                                                                   17
# Sulfonamides, plain                                                                                16
# Other peripheral vasodilators                                                                      16
# Organic nitrates                                                                                   16
# Other ophthalmologicals                                                                            16
# Osmotically acting laxatives                                                                       16
# ACE inhibitors, plain                                                                              16
# Other hypnotics and sedatives                                                                      16
# Angiotensin II receptor blockers (ARBs) and calcium channel blockers                               16
# Anticholinergics                                                                                   16
# Electrolyte solutions                                                                              16
# ACE inhibitors and calcium channel blockers                                                        16
# Other cardiac preparations                                                                         15
# Corticosteroids, plain                                                                             15
# Other drugs for functional gastrointestinal disorders                                              15
# Other nervous system drugs                                                                         15
# Centrally acting antiobesity products                                                              15
# Antihistamines for topical use                                                                     15
# Other antiallergics                                                                                14
# Second-generation cephalosporins                                                                   14
# Beta blocking agents, non-selective                                                                14
# Combinations of sulfonamides and trimethoprim, incl. derivatives                                   14
# Local anesthetics                                                                                  14
# Anticholinesterases                                                                                14
# Beta blocking agents, selective                                                                    14
# Sympathomimetics, plain                                                                            14
# Aminoalkyl ethers                                                                                  14
# Macrolides                                                                                         14
# Other antiinflammatory and antirheumatic agents, non-steroids                                      14
# Sulfonamides and potassium in combination                                                          14
# Centrally acting sympathomimetics                                                                  14
# Drugs for urinary frequency and incontinence                                                       13
# Other antivirals                                                                                   13
# Other aminoglycosides                                                                              13
# Pyrazolones                                                                                        13
# Mucolytics                                                                                         13
# Nucleoside and nucleotide reverse transcriptase inhibitors                                         13
# Sulfonylureas                                                                                      13
# Progestogens                                                                                       13
# Other antibiotics for topical use                                                                  13
# Medicated dressings with antiinfectives                                                            13
# Nitroimidazole derivatives                                                                         13
# Other antiinfectives and antiseptics                                                               13
# ACE inhibitors, other combinations                                                                 13
# Carbapenems                                                                                        12
# Sympathomimetics used as decongestants                                                             12
# Ergot alkaloids                                                                                    12
# Dipeptidyl peptidase 4 (DPP-4) inhibitors                                                          12
# Watersoluble, nephrotropic, low osmolar X-ray contrast media                                       12
# Pyrimidine analogues                                                                               12
# Other antibacterials                                                                               12
# ACE inhibitors and diuretics                                                                       12
# Nucleosides and nucleotides excl. reverse transcriptase inhibitors                                 12
# Antiallergic agents, excl. corticosteroids                                                         12
# First-generation cephalosporins                                                                    12
# Nicotinic acid and derivatives                                                                     11
# Respiratory stimulants                                                                             11
# Beta blocking agents, other combinations                                                           11
# Antiinflammatory agents, non-steroids                                                              11
# Other antiinfectives                                                                               11
# Technetium (99mTc) compounds                                                                       11
# Fibrates                                                                                           11
# Other quaternary ammonium compounds                                                                11
# Substituted alkylamines                                                                            11
# Calcium                                                                                            11
# Carbamic acid esters                                                                               11
# Drugs used in erectile dysfunction                                                                 11
# Other agents against amoebiasis and other protozoal diseases                                       11
# Anthracyclines and related substances                                                              11
# Proton pump inhibitors                                                                             11
# Phenothiazine derivatives                                                                          11
# Other centrally acting agents                                                                      11
# Contact laxatives                                                                                  11
# Other antiemetics                                                                                  11
# Paramagnetic contrast media                                                                        11
# Barbiturates, combinations                                                                         11
# Other plain vitamin preparations                                                                   11
# Parasympathomimetics                                                                               11
# Other agents for treatment of hemorrhoids and anal fissures for topical use                        11
# Opium alkaloids and derivatives                                                                    10
# Detoxifying agents for antineoplastic treatment                                                    10
# Quaternary ammonium compounds                                                                      10
# Heparin group                                                                                      10
# Phenothiazines with piperazine structure                                                           10
# Quinoline derivatives                                                                              10
# Anilides                                                                                           10
# Angiotensin II receptor blockers (ARBs), plain                                                     10
# Magnesium                                                                                          10
# Beta-lactamase sensitive penicillins                                                               10
# Watersoluble, hepatotropic X-ray contrast media                                                    10
# Beta blocking agents                                                                               10
# Other general anesthetics                                                                          10
# Synthetic anticholinergic agents in combination with psycholeptics                                 10
# Watersoluble, nephrotropic, high osmolar X-ray contrast media                                      10
# Other antipsychotics                                                                               10
# Vitamin K antagonists                                                                              10
# Butyrophenone derivatives                                                                          10
# Other diagnostic radiopharmaceuticals for tumour detection                                         10
# H2-receptor antagonists                                                                            10
# Drugs for treatment of hyperkalemia and hyperphosphatemia                                          10
# Tertiary amines                                                                                    10
# Thiazides, plain                                                                                   10
# Antiarrhythmics, class Ia                                                                          10
# Piperazine derivatives                                                                             10
# Beta blocking agents and calcium channel blockers                                                  10
# Other antiseptics and disinfectants                                                                 9
# Digitalis glycosides                                                                                9
# Dopamine agonists                                                                                   9
# Other diagnostic agents                                                                             9
# Androstan derivatives                                                                               9
# Other urologicals                                                                                   9
# Propulsives                                                                                         9
# Protease inhibitors                                                                                 9
# Other analgesics and antipyretics                                                                   9
# Low-ceiling diuretics and potassium-sparing agents                                                  9
# Synthetic anticholinergics, esters with tertiary amino group                                        9
# Antiinfectives for treatment of acne                                                                9
# Nitrogen mustard analogues                                                                          9
# Other respiratory system products                                                                   9
# Rauwolfia alkaloids and diuretics in combination                                                    9
# Renin-inhibitors                                                                                    9
# Biguanides                                                                                          9
# Iron bivalent, oral preparations                                                                    9
# Long-acting sulfonamides                                                                            9
# Angiotensin II receptor blockers (ARBs) and diuretics                                               9
# Selective serotonin reuptake inhibitors                                                             9
# Prostaglandins                                                                                      9
# Retinoids for topical use in acne                                                                   9
# Bioflavonoids                                                                                       8
# Other drugs for treatment of tuberculosis                                                           8
# Pregnadien derivatives                                                                              8
# Other immunosuppressants                                                                            8
# Short-acting sulfonamides                                                                           8
# HMG CoA reductase inhibitors                                                                        8
# Estren derivatives                                                                                  8
# Other antipsoriatics for topical use                                                                8
# Substituted ethylene diamines                                                                       8
# Liver therapy                                                                                       8
# Nitrosoureas                                                                                        8
# Expectorants                                                                                        8
# Natural and semisynthetic estrogens, plain                                                          8
# Guanidine derivatives                                                                               8
# Selective serotonin (5HT1) agonists                                                                 8
# Other quinolones                                                                                    8
# Bisphosphonates                                                                                     8
# Prostaglandin analogues                                                                             8
# Rauwolfia alkaloids                                                                                 8
# Antipropulsives                                                                                     8
# Other opioids                                                                                       8
# Other cicatrizants                                                                                  8
# Epidermal growth factor receptor (EGFR) tyrosine kinase inhibitors                                  8
# Other immunostimulants                                                                              8
# Phenothiazines with aliphatic side-chain                                                            7
# Sodium-glucose co-transporter 2 (SGLT2) inhibitors                                                  7
# Other nasal preparations                                                                            7
# Halogenated hydrocarbons                                                                            7
# Benzamides                                                                                          7
# Other drugs for constipation                                                                        7
# Vitamin D and analogues                                                                             7
# Non-selective beta-adrenoreceptor agonists                                                          7
# Corticosteroids acting locally                                                                      7
# Coxibs                                                                                              7
# Other lipid modifying agents                                                                        7
# Hydantoin derivatives                                                                               7
# Anti-gonadotropin-releasing hormones                                                                7
# Iron in other combinations                                                                          7
# Drugs used in opioid dependence                                                                     7
# Diphenylpropylamine derivatives                                                                     7
# Gonadotropin releasing hormone analogues                                                            7
# Opioid anesthetics                                                                                  7
# Nitrofuran derivatives                                                                              7
# Esters of aminobenzoic acid                                                                         7
# Ascorbic acid (vitamin C), combinations                                                             7
# Anesthetics for topical use                                                                         7
# Other blood glucose lowering drugs, excl. insulins                                                  7
# Beta blocking agents, selective, and thiazides                                                      7
# Antihypertensives for pulmonary arterial hypertension                                               7
# Estrogens, combinations with other drugs                                                            7
# Sympathomimetics, combinations excl. corticosteroids                                                7
# Benzimidazole derivatives                                                                           7
# Mercurial products                                                                                  6
# Hydroxyquinoline derivatives                                                                        6
# Dopa and dopa derivatives                                                                           6
# Iron trivalent, oral preparations                                                                   6
# Pyrethrines, incl. synthetic compounds                                                              6
# Poly (ADP-ribose) polymerase (PARP) inhibitors                                                      6
# Androgens and estrogens                                                                             6
# Carbonic anhydrase inhibitors                                                                       6
# Sensitizers used in photodynamic/radiation therapy                                                  6
# Belladonna alkaloids, semisynthetic, quaternary ammonium compounds                                  6
# Monoamine oxidase inhibitors, non-selective                                                         6
# Phenol and derivatives                                                                              6
# Anti-androgens                                                                                      6
# Other drugs for disorders of the musculo-skeletal system                                            6
# BCR-ABL tyrosine kinase inhibitors                                                                  6
# Biguanides and amidines                                                                             6
# Oxicams                                                                                             6
# Aluminium compounds                                                                                 6
# Sympathomimetics in glaucoma therapy                                                                6
# Other systemic hemostatics                                                                          6
# Corticosteroids, potent, combinations with antibiotics                                              6
# Enemas                                                                                              6
# Prolactine inhibitors                                                                               6
# Vinca alkaloids and analogues                                                                       6
# Tests for gastric secretion                                                                         6
# Beta blocking agents, non-selective, and thiazides                                                  6
# Serotonin (5HT3) antagonists                                                                        6
# Agents for dermatitis, excluding corticosteroids                                                    6
# Other anti-acne preparations for topical use                                                        6
# Triazole and tetrazole derivatives                                                                  6
# Purine analogues                                                                                    6
# Xanthines and adrenergics                                                                           6
# Non-nucleoside reverse transcriptase inhibitors                                                     6
# Sympathomimetics                                                                                    6
# Amino acids                                                                                         6
# Beta-lactamase resistant penicillins                                                                6
# Other insecticides and repellents                                                                   6
# Aromatase inhibitors                                                                                6
# Amino acids and derivatives                                                                         6
# Oxazol, thiazine, and triazine derivatives                                                          6
# Diazepines, oxazepines, thiazepines and oxepines                                                    6
# Thioxanthene derivatives                                                                            5
# Indole derivatives                                                                                  5
# Arsenic compounds                                                                                   5
# Antivertigo preparations                                                                            5
# Imidazoline receptor agonists                                                                       5
# Other antimigraine preparations                                                                     5
# Sulfur containing products                                                                          5
# Direct thrombin inhibitors                                                                          5
# Butylpyrazolidines                                                                                  5
# Fatty acid derivatives                                                                              5
# Other ectoparasiticides, incl. scabicides                                                           5
# Local hemostatics                                                                                   5
# Other agents for local oral treatment                                                               5
# Phenylalkylamine derivatives                                                                        5
# Drugs used in alcohol dependence                                                                    5
# Anaplastic lymphoma kinase (ALK) inhibitors                                                         5
# Corticosteroids, moderately potent, other combinations                                              5
# Other drugs for bile therapy                                                                        5
# Potassium                                                                                           5
# Corticosteroids, moderately potent, combinations with antibiotics                                   5
# Corticosteroids/antiinfectives/mydriatics in combination                                            5
# Aminoquinolines                                                                                     5
# Artemisinin and derivatives, plain                                                                  5
# Medical gases                                                                                       5
# Iodine (131I) compounds                                                                             5
# Synthetic anticholinergic agents in combination with analgesics                                     5
# Phenylpiperidine derivatives                                                                        5
# Antiarrhythmics, class Ic                                                                           5
# Other drugs affecting bone structure and mineralization                                             5
# Barbiturates and derivatives                                                                        5
# Sclerosing agents for local injection                                                               5
# Hypnotics and sedatives in combination, excl. barbiturates                                          5
# Leukotriene receptor antagonists                                                                    5
# Corticosteroids, potent, other combinations                                                         5
# Caries prophylactic agents                                                                          5
# Histone deacetylase (HDAC) inhibitors                                                               5
# Aldehydes and derivatives                                                                           5
# Selective estrogen receptor modulators                                                              5
# Preparations increasing uric acid excretion                                                         5
# Aldosterone antagonists                                                                             5
# Peripheral opioid receptor antagonists                                                              5
# Magnesium compounds                                                                                 5
# Other systemic drugs for obstructive airway diseases                                                5
# Gold preparations                                                                                   5
# Glycopeptide antibacterials                                                                         5
# Other anti-parathyroid agents                                                                       5
# Sympathomimetics excl. antiglaucoma preparations                                                    5
# Benzodiazepine related drugs                                                                        4
# Hydrazinophthalazine derivatives                                                                    4
# Synthetic estrogens, plain                                                                          4
# Salt solutions                                                                                      4
# Estrogens                                                                                           4
# Antiarrhythmics, class Ib                                                                           4
# Thyroid hormones                                                                                    4
# Anesthetics, local                                                                                  4
# Other intestinal adsorbents                                                                         4
# Bile acids and derivatives                                                                          4
# Analgesics and anesthetics                                                                          4
# Other hormone antagonists and related agents                                                        4
# Other cytotoxic antibiotics                                                                         4
# Folic acid analogues                                                                                4
# Opioids in combination with antispasmodics                                                          4
# Pyrethrines                                                                                         4
# Neuraminidase inhibitors                                                                            4
# Topoisomerase 1 (TOP1) inhibitors                                                                   4
# Aminosalicylic acid and similar agents                                                              4
# Non-watersoluble X-ray contrast media                                                               4
# Beta blocking agents, non-selective, and other diuretics                                            4
# Other cephalosporins and penems                                                                     4
# Other intestinal antiinfectives                                                                     4
# Combinations and complexes of aluminium, calcium and magnesium compounds                            4
# Phosphodiesterase inhibitors                                                                        4
# Other alkylating agents                                                                             4
# Thiazolidinediones                                                                                  4
# Mitogen-activated protein kinase (MEK) inhibitors                                                   4
# Integrase inhibitors                                                                                4
# Dichloroacetamide derivatives                                                                       4
# Somatostatin and analogues                                                                          4
# Purine derivatives                                                                                  4
# Other antitrematodal agents                                                                         4
# Other topical products for joint and muscular pain                                                  4
# Direct factor Xa inhibitors                                                                         4
# Antiinflammatory products for vaginal administration                                                4
# Fenamates                                                                                           4
# Taxanes                                                                                             4
# Acid preparations                                                                                   4
# Other antiglaucoma preparations                                                                     4
# Tests for bile duct patency                                                                         4
# Other agents against leishmaniasis and trypanosomiasis                                              4
# Preparations inhibiting uric acid production                                                        4
# Succinimide derivatives                                                                             4
# Tetracycline and derivatives                                                                        4
# Other central nervous system diagnostic radiopharmaceuticals                                        4
# Carbamates                                                                                          4
# Blood substitutes and plasma protein fractions                                                      4
# Corticosteroids, moderately potent, combinations with antiseptics                                   4
# Corticosteroids for local oral treatment                                                            4
# Carboxamide derivatives                                                                             4
# Corticosteroids and mydriatics in combination                                                       4
# Corticosteroids, potent, combinations with antiseptics                                              4
# Other dopaminergic agents                                                                           4
# Tests for renal function and ureteral injuries                                                      4
# Other antimycotics for systemic use                                                                 4
# Fibroblast growth factor receptor (FGFR) tyrosine kinase inhibitors                                 4
# Phenothiazines with piperidine structure                                                            4
# Other anxiolytics                                                                                   4
# Belladonna and derivatives in combination with psycholeptics                                        4
# Other local anesthetics                                                                             4
# Heparins or heparinoids for topical use                                                             4
# Pregnen (4) derivatives                                                                             4
# Phosphatidylinositol-3-kinase (Pi3K) inhibitors                                                     4
# Platinum compounds                                                                                  4
# Xanthine derivatives                                                                                3
# Piperidinedione derivatives                                                                         3
# Diphenylbutylpiperidine derivatives                                                                 3
# Other parasympathomimetics                                                                          3
# Proteasome inhibitors                                                                               3
# Tests for pituitary function                                                                        3
# B-Raf serine-threonine kinase (BRAF) inhibitors                                                     3
# Alkyl sulfonates                                                                                    3
# Iodine products                                                                                     3
# Monoamine oxidase B inhibitors                                                                      3
# 2-amino-1-phenylethanol derivatives                                                                 3
# Papaverine and derivatives                                                                          3
# Anticorticosteroids                                                                                 3
# Intermediate-acting sulfonamides                                                                    3
# Melatonin receptor agonists                                                                         3
# Vitamin B1, plain                                                                                   3
# Vascular endothelial growth factor receptor (VEGFR) tyrosine kinase inhibitors                      3
# Hydrazinophthalazine derivatives and diuretics                                                      3
# Medicated shampoos                                                                                  3
# Calcineurin inhibitors                                                                              3
# Antifungals for systemic use                                                                        3
# Mammalian target of rapamycin (mTOR) kinase inhibitors                                              3
# Sulfur-containing imidazole derivatives                                                             3
# Fourth-generation cephalosporins                                                                    3
# Chlorine containing products                                                                        3
# Organic acids                                                                                       3
# Trimethoprim and derivatives                                                                        3
# Other antianemic preparations                                                                       3
# Human epidermal growth factor receptor 2 (HER2) tyrosine kinase inhibitors                          3
# Amphenicols                                                                                         3
# Other irrigating solutions                                                                          3
# Ethylene imines                                                                                     3
# Anti-estrogens                                                                                      3
# Bile acid sequestrants                                                                              3
# Preparations containing sulfur                                                                      3
# Enzymes                                                                                             3
# Various thyroid diagnostic radiopharmaceuticals                                                     3
# Colouring agents                                                                                    3
# Acridine derivatives                                                                                3
# Iron chelating agents                                                                               3
# Drugs for treatment of lepra                                                                        3
# Sympathomimetics, labour repressants                                                                3
# Other antinematodals                                                                                3
# Corticosteroids, weak, combinations with antibiotics                                                3
# Imidazoline receptor agonists in combination with diuretics                                         3
# Beta blocking agents, selective, and other diuretics                                                3
# Hedgehog pathway inhibitors                                                                         3
# Progesterone receptor modulators                                                                    3
# Cyclin-dependent kinase (CDK) inhibitors                                                            3
# Antiinflammatory/antirheumatic agents in combination with corticosteroids                           3
# Calcitonin gene-related peptide (CGRP) antagonists                                                  3
# Antidepressants in combination with psycholeptics                                                   3
# 3-oxoandrosten (4) derivatives                                                                      3
# Synthetic antispasmodics, amides with tertiary amines                                               3
# Viscoelastic substances                                                                             3
# Corticosteroids, combinations for treatment of acne                                                 3
# Janus-associated kinase (JAK) inhibitors                                                            3
# Thiocarbamide derivatives                                                                           3
# Alpha glucosidase inhibitors                                                                        3
# Other chemotherapeutics                                                                             3
# Mineralocorticoids                                                                                  3
# Other throat preparations                                                                           3
# Bruton's tyrosine kinase (BTK) inhibitors                                                           3
# Aminosalicylic acid and derivatives                                                                 3
# Oxazolidine derivatives                                                                             3
# Retinoids for cancer treatment                                                                      3
# Ovulation stimulants, synthetic                                                                     3
# Other therapeutic products                                                                          3
# Thiouracils                                                                                         3
# Diphenylmethane derivatives                                                                         3
# Muscle relaxants                                                                                    3
# Psoralens for systemic use                                                                          3
# Iron in combination with folic acid                                                                 2
# Iodine (123I) compounds                                                                             2
# Softeners, emollients                                                                               2
# Selenium                                                                                            2
# ...
# Benzomorphan derivatives                                                                            2
# Methanolquinolines                                                                                  2
# High-ceiling diuretics and potassium-sparing agents                                                 2
# Corticosteroids, weak, other combinations                                                           2
# Corticosteroids, weak, combinations with antiseptics                                                2
# Monobactams                                                                                         2
# Solutions producing osmotic diuresis                                                                2
# Thiazides, combinations with psycholeptics and/or analgesics                                        2
# Antiandrogens and estrogens                                                                         2
# Polymyxins                                                                                          2
# Penicillamine and similar agents                                                                    2
# Vasopressin antagonists                                                                             2
# Aryloxyacetic acid derivatives                                                                      2
# Antiinflammatory agents, non-steroids and antiinfectives in combination                             2
# Other cardiac stimulants                                                                            2
# Hydrazides                                                                                          2
# Serotonin receptor antagonists                                                                      2
# Combinations of antineoplastic agents                                                               2
# Imidazoline derivatives                                                                             2
# Diaminopyrimidines                                                                                  2
# Emergency contraceptives                                                                            2
# Retinoids for treatment of psoriasis                                                                2
# Quinine and derivatives                                                                             2
# Cyclic amines                                                                                       2
# Tests for pancreatic function                                                                       2
# Psoralens for topical use                                                                           2
# Other antithrombotic agents                                                                         2
# Alpha and beta blocking agents                                                                      2
# Podophyllotoxin derivatives                                                                         2
# Belladonna alkaloids, tertiary amines                                                               2
# Morphinan derivatives                                                                               2
# Choline esters                                                                                      2
# Gonadotropin-releasing hormones                                                                     2
# Other potassium-sparing agents                                                                      2
# Calcium channel blockers and diuretics                                                              2
# Alpha- and beta-adrenoreceptor agonists                                                             2
# Ethers of tropine or tropine derivatives                                                            2
# Antineovascularisation agents                                                                       2
# Acidifiers                                                                                          2
# Vitamin A, plain                                                                                    2
# Ethers chemically close to antihistamines                                                           2
# Lincosamides                                                                                        2
# Curare alkaloids                                                                                    2
# Other antimalarials                                                                                 2
# Testosterone-5-alpha reductase inhibitors                                                           2
# Folic acid and derivatives                                                                          2
# Oxytocin and analogues                                                                              2
# Multivitamins with minerals                                                                         2
# Ethers, chemically close to antihistamines                                                          2
# Strophanthus glycosides                                                                             2
# Monoamine oxidase A inhibitors                                                                      2
# Preparations with no effect on uric acid metabolism                                                 2
# Other non-selective calcium channel blockers                                                        2
# Beta-lactamase inhibitors                                                                           2
# Quinoline derivatives and related substances                                                        2
# Antigonadotropins and similar agents                                                                2
# Vasopressin and analogues                                                                           2
# Drugs used in nicotine dependence                                                                   2
# Other cardiac glycosides                                                                            1
# Calcitonin preparations                                                                             1
# Technetium (99mTc), particles and colloids                                                          1
# Proteinase inhibitors                                                                               1
# Glucagon-like peptide-1 (GLP-1) analogues                                                           1
# Streptogramins                                                                                      1
# Solutions for parenteral nutrition                                                                  1
# Pyrazolone derivatives                                                                              1
# Beta blocking agents, non-selective, thiazides and other diuretics                                  1
# Tests for thyreoidea function                                                                       1
# Perchlorates                                                                                        1
# Other hematological agents                                                                          1
# Proteolytic enzymes                                                                                 1
# Alpha-adrenoreceptor antagonists and diuretics                                                      1
# Choline derivatives                                                                                 1
# Thiosemicarbazones                                                                                  1
# Other antiparkinson drugs                                                                           1
# Barbiturates in combination with other drugs                                                        1
# Quinolone vasodilators                                                                              1
# Triazole derivatives                                                                                1
# Nitroferricyanide derivatives                                                                       1
# Yttrium (90Y) compounds                                                                             1
# Epoxides                                                                                            1
# Other surgical aids                                                                                 1
# Serotonin antagonists                                                                               1
# Beta blocking agents, selective, thiazides and other diuretics                                      1
# Indium (111In) compounds                                                                            1
# Tests for fat absorption                                                                            1
# Other drugs used in benign prostatic hypertrophy                                                    1
# Corticosteroids, very potent, combinations with antibiotics                                         1
# Androgens for topical use                                                                           1
# Benzothiazepine derivatives                                                                         1
# Quinolines                                                                                          1
# Pyrimidine derivatives                                                                              1
# Ergot alkaloids and oxytocin incl. analogues, in combination                                        1
# Organophosphorous compounds                                                                         1
# Ascorbic acid (vitamin C), plain                                                                    1
# Corticosteroid derivatives                                                                          1
# Colchicine derivatives                                                                              1
# Other low-ceiling diuretics                                                                         1
# Other sex hormones and modulators of the genital system                                             1
# Various therapeutic radiopharmaceuticals                                                            1
# Methyldopa                                                                                          1
# Retinoids for treatment of acne                                                                     1
# Other antiobesity drugs                                                                             1
# Antihidrotics                                                                                       1
# Other magnetic resonance imaging contrast media                                                     1
# Thiazides, combinations with other drugs                                                            1
# Other anti-dementia drugs                                                                           1
# Streptomycins                                                                                       1
# Other plant alkaloids and natural products                                                          1
# Peripherally acting antiobesity products                                                            1
# Sulfonium derivatives                                                                               1
# Thiazide derivatives                                                                                1
# Drugs for treatment of hypoglycemia                                                                 1
# Tests for diabetes                                                                                  1
# Other antipruritics                                                                                 1
# Antiandrogens, plain                                                                                1
# Methylhydrazines                                                                                    1
# Guanidine derivatives and diuretics                                                                 1
# Dantrolene and derivatives                                                                          1
# Carbohydrates                                                                                       1
# Solutions affecting the electrolyte balance                                                         1
# Other i.v. solution additives                                                                       1
# Other selective calcium channel blockers with mainly vascular effects                               1
# Steroid antibacterials                                                                              1
# Aldose reductase inhibitors                                                                         1
# MAO inhibitors and diuretics                                                                        1
# Actinomycines                                                                                       1
# Corticosteroids for systemic use, combinations                                                      1
# Mercurial diuretics                                                                                 1
# Oripavine derivatives                                                                               1
# Azaspirodecanedione derivatives                                                                     1
# Belladonna and derivatives in combination with analgesics                                           1
# Phosphonic acid derivatives                                                                         1
# Alpha and beta blocking agents and thiazides                                                        1
# Alpha and beta blocking agents and other diuretics                                                  1
# Avermectines                                                                                        1
# Lung surfactants                                                                                    1
# Tests for fertility disturbances                                                                    1
# Other estrogens                                                                                     1
# MAO inhibitors                                                                                      1
# Secondary and tertiary amines                                                                       1
# Dibenzo-bicyclo-octadiene derivatives                                                               1
# Other drugs for obstructive airway diseases, inhalants                                              1
# Antacids with antiflatulents                                                                        1
# Preparations for biliary tract therapy                                                              1
# Tyrosine hydroxylase inhibitors                                                                     1
# Other antithyroid preparations                                                                      1
# Intravaginal contraceptives                                                                         1
# Imidazothiazole derivatives                                                                         1
# Salicylic acid derivatives                                                                          1
# Nerve depressants                                                                                   1
# Other antihypertensives and diuretics                                                               1
# Esters of benzoic acid                                                                              1
# Adamantane derivatives                                                                              1
# Androgens and female sex hormones in combination with other drugs                                   1
# Other cardiovascular system diagnostic radiopharmaceuticals                                         1
# dtype: int64

# %% [markdown]
# Далее для модели будут использованы основные классы препаратов, применяемые в терапии (ингибиторы АПФ, блокаторы рецепторов к ангиотензину 2, бета-блокаторы, барбитураты, гистаминовые блокаторы, бензодиазепины, блокаторы кальциевых каналов произвоные дигидроперидина).
# Для использования в датасет не входят комбинации препаратов, препараты без определенной химической группы ("Others...").

# %%
# Датасет для ингибиторов АПФ.

ingib_ace_df = df_sm[df_sm['codes'].str.contains('ACE inhibitors, plain')]

# %%
ingib_ace_df.shape
# Out:
# (16, 6)

# %%
ingib_ace_df['p_np'] = 'ingib_ace'

ingib_ace_df.head()
# Out:
#          drugname       drug_type                           groups  \
# 72       Ramipril  small molecule                     ['approved']
# 384    Fosinopril  small molecule                     ['approved']
# 409  Trandolapril  small molecule                     ['approved']
# 432    Benazepril  small molecule  ['approved', 'investigational']
# 474     Enalapril  small molecule     ['approved', 'vet_approved']
#
#                                                  codes  \
# 72   ['ACE inhibitors, other combinations', 'ACE IN...
# 384  ['ACE inhibitors and diuretics', 'ACE INHIBITO...
# 409  ['ACE inhibitors, plain', 'ACE INHIBITORS, PLA...
# 432  ['ACE inhibitors and diuretics', 'ACE INHIBITO...
# 474  ['ACE inhibitors and diuretics', 'ACE INHIBITO...
#
#                                                 smiles  \
# 72   [H][C@@]12CCC[C@]1([H])N([C@@H](C2)C(O)=O)C(=O...
# 384  CCC(=O)O[C@@H](OP(=O)(CCCCC1=CC=CC=C1)CC(=O)N1...
# 409  [H][C@@]12C[C@H](N(C(=O)[C@H](C)N[C@@H](CCC3=C...
# 432  [H][C@@]1(CCC2=CC=CC=C2N(CC(O)=O)C1=O)N[C@@H](...
# 474  CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1C...
#
#                                   atc_4       p_np
# 72   ACE inhibitors, other combinations  ingib_ace
# 384        ACE inhibitors and diuretics  ingib_ace
# 409               ACE inhibitors, plain  ingib_ace
# 432        ACE inhibitors and diuretics  ingib_ace
# 474        ACE inhibitors and diuretics  ingib_ace

# %%
# Датасет для бета-блокаторов (селективных и неселективных).

beta_block_df = df_sm[df_sm['codes'].str.contains('Beta blocking agents, non-selective') |\
                      df_sm['codes'].str.contains('Beta blocking agents, selective')]

# %%
beta_block_df.shape
# Out:
# (29, 6)

# %%
beta_block_df['p_np'] = 'beta_block'

beta_block_df.head()
# Out:
#        drugname       drug_type                           groups  \
# 81      Esmolol  small molecule        ['approved', 'withdrawn']
# 89    Betaxolol  small molecule  ['approved', 'investigational']
# 158  Metoprolol  small molecule  ['approved', 'investigational']
# 228    Atenolol  small molecule                     ['approved']
# 266     Timolol  small molecule                     ['approved']
#
#                                                  codes  \
# 81   ['Beta blocking agents, selective', 'BETA BLOC...
# 89   ['Beta blocking agents', 'ANTIGLAUCOMA PREPARA...
# 158  ['Beta blocking agents and calcium channel blo...
# 228  ['Beta blocking agents, selective, and other d...
# 266  ['Beta blocking agents, non-selective', 'BETA ...
#
#                                         smiles  \
# 81         COC(=O)CCC1=CC=C(OCC(O)CNC(C)C)C=C1
# 89         CC(C)NCC(O)COC1=CC=C(CCOCC2CC2)C=C1
# 158             COCCC1=CC=C(OCC(O)CNC(C)C)C=C1
# 228          CC(C)NCC(O)COC1=CC=C(CC(N)=O)C=C1
# 266  [H][C@](O)(CNC(C)(C)C)COC1=NSN=C1N1CCOCC1
#
#                                                  atc_4        p_np
# 81                     Beta blocking agents, selective  beta_block
# 89                                Beta blocking agents  beta_block
# 158  Beta blocking agents and calcium channel blockers  beta_block
# 228  Beta blocking agents, selective, and other diu...  beta_block
# 266                Beta blocking agents, non-selective  beta_block

# %%
# Датасет для барбитуратов.

barbit_df = df_sm[df_sm['codes'].str.contains('Barbiturates, plain')]

barbit_df.shape
# Out:
# (17, 6)

# %%
barbit_df['p_np'] = 'barbiturat'

barbit_df.head()
# Out:
#           drugname       drug_type  \
# 200       Talbutal  small molecule
# 206  Pentobarbital  small molecule
# 310   Secobarbital  small molecule
# 366   Methohexital  small molecule
# 489     Thiopental  small molecule
#
#                                               groups  \
# 200                          ['approved', 'illicit']
# 206  ['approved', 'investigational', 'vet_approved']
# 310                     ['approved', 'vet_approved']
# 366                                     ['approved']
# 489                     ['approved', 'vet_approved']
#
#                                                  codes  \
# 200  ['Barbiturates, plain', 'HYPNOTICS AND SEDATIV...
# 206  ['Barbiturates, combinations', 'HYPNOTICS AND ...
# 310  ['Barbiturates, combinations', 'HYPNOTICS AND ...
# 366  ['Barbiturates, combinations', 'HYPNOTICS AND ...
# 489  ['Barbiturates, plain', 'ANESTHETICS, GENERAL'...
#
#                                    smiles                       atc_4  \
# 200        CCC(C)C1(CC=C)C(=O)NC(=O)NC1=O         Barbiturates, plain
# 206         CCCC(C)C1(CC)C(=O)NC(=O)NC1=O  Barbiturates, combinations
# 310       CCCC(C)C1(CC=C)C(=O)NC(=O)NC1=O  Barbiturates, combinations
# 366  CCC#CC(C)C1(CC=C)C(=O)NC(=O)N(C)C1=O  Barbiturates, combinations
# 489         CCCC(C)C1(CC)C(=O)NC(=S)NC1=O         Barbiturates, plain
#
#            p_np
# 200  barbiturat
# 206  barbiturat
# 310  barbiturat
# 366  barbiturat
# 489  barbiturat

# %%
# Датасет для блокаторов кальциевых каналов.
# Взяты только производные дигидроперидина, как самый большой класс среди этой группы.

ca_chan_block_dihidro_df = df_sm[df_sm['codes'].str.contains('Dihydropyridine derivatives')]
ca_chan_block_dihidro_df = ca_chan_block_dihidro_df.drop([374]) # Удален Celecoxib, т.к. относится к противовоспалительным.

ca_chan_block_dihidro_df.head()
# Out:
#           drugname       drug_type                           groups  \
# 164     Isradipine  small molecule  ['approved', 'investigational']
# 274     Amlodipine  small molecule                     ['approved']
# 285     Nimodipine  small molecule  ['approved', 'investigational']
# 293    Nisoldipine  small molecule                     ['approved']
# 418  Lercanidipine  small molecule  ['approved', 'investigational']
#
#                                                  codes  \
# 164  ['Dihydropyridine derivatives', 'SELECTIVE CAL...
# 274  ['Renin-inhibitors', 'OTHER AGENTS ACTING ON T...
# 285  ['Dihydropyridine derivatives', 'SELECTIVE CAL...
# 293  ['Dihydropyridine derivatives', 'SELECTIVE CAL...
# 418  ['Angiotensin II receptor blockers (ARBs) and ...
#
#                                                 smiles  \
# 164  COC(=O)C1=C(C)NC(C)=C(C1C1=CC=CC2=NON=C12)C(=O...
# 274  CCOC(=O)C1=C(COCCN)NC(C)=C(C1C1=CC=CC=C1Cl)C(=...
# 285  COCCOC(=O)C1=C(C)NC(C)=C(C1C1=CC(=CC=C1)[N+]([...
# 293  COC(=O)C1=C(C)NC(C)=C(C1C1=CC=CC=C1[N+]([O-])=...
# 418  COC(=O)C1=C(C)NC(C)=C(C1C1=CC(=CC=C1)[N+]([O-]...
#
#                                                  atc_4
# 164                        Dihydropyridine derivatives
# 274                                   Renin-inhibitors
# 285                        Dihydropyridine derivatives
# 293                        Dihydropyridine derivatives
# 418  Angiotensin II receptor blockers (ARBs) and ca...

# %%
ca_chan_block_dihidro_df.shape
# Out:
# (17, 6)

# %%
ca_chan_block_dihidro_df['p_np'] = 'ca_chan_block_dihidro'

ca_chan_block_dihidro_df.head()
# Out:
#           drugname       drug_type                           groups  \
# 164     Isradipine  small molecule  ['approved', 'investigational']
# 274     Amlodipine  small molecule                     ['approved']
# 285     Nimodipine  small molecule  ['approved', 'investigational']
# 293    Nisoldipine  small molecule                     ['approved']
# 418  Lercanidipine  small molecule  ['approved', 'investigational']
#
#                                                  codes  \
# 164  ['Dihydropyridine derivatives', 'SELECTIVE CAL...
# 274  ['Renin-inhibitors', 'OTHER AGENTS ACTING ON T...
# 285  ['Dihydropyridine derivatives', 'SELECTIVE CAL...
# 293  ['Dihydropyridine derivatives', 'SELECTIVE CAL...
# 418  ['Angiotensin II receptor blockers (ARBs) and ...
#
#                                                 smiles  \
# 164  COC(=O)C1=C(C)NC(C)=C(C1C1=CC=CC2=NON=C12)C(=O...
# 274  CCOC(=O)C1=C(COCCN)NC(C)=C(C1C1=CC=CC=C1Cl)C(=...
# 285  COCCOC(=O)C1=C(C)NC(C)=C(C1C1=CC(=CC=C1)[N+]([...
# 293  COC(=O)C1=C(C)NC(C)=C(C1C1=CC=CC=C1[N+]([O-])=...
# 418  COC(=O)C1=C(C)NC(C)=C(C1C1=CC(=CC=C1)[N+]([O-]...
#
#                                                  atc_4                   p_np
# 164                        Dihydropyridine derivatives  ca_chan_block_dihidro
# 274                                   Renin-inhibitors  ca_chan_block_dihidro
# 285                        Dihydropyridine derivatives  ca_chan_block_dihidro
# 293                        Dihydropyridine derivatives  ca_chan_block_dihidro
# 418  Angiotensin II receptor blockers (ARBs) and ca...  ca_chan_block_dihidro

# %%
# Датасет для блокаторов рецепторов к ангиотензину 2.

sartan_df = df_sm[df_sm['codes'].str.contains('ARBs') &
                  df_sm['codes'].str.contains('plain')]
sartan_df = sartan_df.drop([885]) # Удален гидрохлортиазид, т.к. относится к другой группе.

# %%
sartan_df.shape
# Out:
# (10, 6)

# %%
sartan_df['p_np'] = 'ARBs'

sartan_df.head()
# Out:
#         drugname       drug_type                           groups  \
# 71     Valsartan  small molecule  ['approved', 'investigational']
# 169   Olmesartan  small molecule  ['approved', 'investigational']
# 566     Losartan  small molecule                     ['approved']
# 762   Eprosartan  small molecule                     ['approved']
# 852  Telmisartan  small molecule  ['approved', 'investigational']
#
#                                                  codes  \
# 71   ['Angiotensin II receptor blockers (ARBs), oth...
# 169  ['Angiotensin II receptor blockers (ARBs) and ...
# 566  ['Angiotensin II receptor blockers (ARBs), pla...
# 762  ['Angiotensin II receptor blockers (ARBs) and ...
# 852  ['Angiotensin II receptor blockers (ARBs) and ...
#
#                                                 smiles  \
# 71   CCCCC(=O)N(CC1=CC=C(C=C1)C1=CC=CC=C1C1=NNN=N1)...
# 169  CCCC1=NC(=C(N1CC1=CC=C(C=C1)C1=C(C=CC=C1)C1=NN...
# 566  CCCCC1=NC(Cl)=C(CO)N1CC1=CC=C(C=C1)C1=CC=CC=C1...
# 762  CCCCC1=NC=C(\C=C(/CC2=CC=CS2)C(O)=O)N1CC1=CC=C...
# 852  CCCC1=NC2=C(C=C(C=C2C)C2=NC3=CC=CC=C3N2C)N1CC1...
#
#                                                  atc_4  p_np
# 71   Angiotensin II receptor blockers (ARBs), other...  ARBs
# 169  Angiotensin II receptor blockers (ARBs) and di...  ARBs
# 566     Angiotensin II receptor blockers (ARBs), plain  ARBs
# 762  Angiotensin II receptor blockers (ARBs) and di...  ARBs
# 852  Angiotensin II receptor blockers (ARBs) and ca...  ARBs

# %%
# Датасет для бензодиазепинов.

benzodiazepin_df = df_sm[df_sm['codes'].str.contains('Benzodiazepine derivatives')]

# %%
benzodiazepin_df.shape
# Out:
# (39, 6)

# %%
benzodiazepin_df['p_np'] = 'benzodiazepin'

benzodiazepin_df.head()
# Out:
#              drugname       drug_type  \
# 80          Lorazepam  small molecule
# 125         Temazepam  small molecule
# 242          Clobazam  small molecule
# 296        Alprazolam  small molecule
# 367  Chlordiazepoxide  small molecule
#
#                                          groups  \
# 80                                 ['approved']
# 125             ['approved', 'investigational']
# 242                     ['approved', 'illicit']
# 296  ['approved', 'illicit', 'investigational']
# 367  ['approved', 'illicit', 'investigational']
#
#                                                  codes  \
# 80   ['Benzodiazepine derivatives', 'ANXIOLYTICS', ...
# 125  ['Benzodiazepine derivatives', 'HYPNOTICS AND ...
# 242  ['Benzodiazepine derivatives', 'ANXIOLYTICS', ...
# 296  ['Benzodiazepine derivatives', 'ANXIOLYTICS', ...
# 367  ['Benzodiazepine derivatives', 'ANXIOLYTICS', ...
#
#                                                 smiles  \
# 80         OC1N=C(C2=CC=CC=C2Cl)C2=C(NC1=O)C=CC(Cl)=C2
# 125       CN1C2=C(C=C(Cl)C=C2)C(=NC(O)C1=O)C1=CC=CC=C1
# 242       CN1C2=C(C=C(Cl)C=C2)N(C2=CC=CC=C2)C(=O)CC1=O
# 296     CC1=NN=C2CN=C(C3=CC=CC=C3)C3=C(C=CC(Cl)=C3)N12
# 367  CNC1=NC2=C(C=C(Cl)C=C2)C(C2=CC=CC=C2)=[N+]([O-...
#
#                           atc_4           p_np
# 80   Benzodiazepine derivatives  benzodiazepin
# 125  Benzodiazepine derivatives  benzodiazepin
# 242  Benzodiazepine derivatives  benzodiazepin
# 296  Benzodiazepine derivatives  benzodiazepin
# 367  Benzodiazepine derivatives  benzodiazepin

# %%
# Датасет для антигистминных препаратов.
# Взяты две подгруппы схожие химически.

anti_hist_df = df_sm[df_sm['codes'].str.contains('Substituted alkylamines') |
                     df_sm['codes'].str.contains('Substituted ethylene diamines')]

# %%
anti_hist_df.shape
# Out:
# (13, 6)

# %%
anti_hist_df['p_np'] = 'anti_hist'

anti_hist_df.head()
# Out:
#                 drugname       drug_type                        groups  \
# 297   Dexbrompheniramine  small molecule                  ['approved']
# 678       Tripelennamine  small molecule  ['approved', 'vet_approved']
# 721      Brompheniramine  small molecule                  ['approved']
# 997     Chlorpheniramine  small molecule                  ['approved']
# 1432         Pheniramine  small molecule                  ['approved']
#
#                                                   codes  \
# 297   ['Substituted alkylamines', 'ANTIHISTAMINES FO...
# 678   ['Substituted ethylene diamines', 'ANTIHISTAMI...
# 721   ['Substituted alkylamines', 'ANTIHISTAMINES FO...
# 997   ['Substituted alkylamines', 'ANTIHISTAMINES FO...
# 1432  ['Substituted alkylamines', 'ANTIHISTAMINES FO...
#
#                                          smiles  \
# 297   CN(C)CC[C@@H](C1=CC=C(Br)C=C1)C1=CC=CC=N1
# 678           CN(C)CCN(CC1=CC=CC=C1)C1=CC=CC=N1
# 721        CN(C)CCC(C1=CC=C(Br)C=C1)C1=CC=CC=N1
# 997        CN(C)CCC(C1=CC=C(Cl)C=C1)C1=CC=CC=N1
# 1432           CN(C)CCC(C1=CC=CC=C1)C1=CC=CC=N1
#
#                               atc_4       p_np
# 297         Substituted alkylamines  anti_hist
# 678   Substituted ethylene diamines  anti_hist
# 721         Substituted alkylamines  anti_hist
# 997         Substituted alkylamines  anti_hist
# 1432        Substituted alkylamines  anti_hist

# %%
# Собираем в общий датасет.

df_red = pd.concat([beta_block_df, ingib_ace_df, barbit_df,
                    ca_chan_block_dihidro_df, benzodiazepin_df,
                    sartan_df, anti_hist_df], ignore_index=True)

df_red.head()
# Out:
#      drugname       drug_type                           groups  \
# 0     Esmolol  small molecule        ['approved', 'withdrawn']
# 1   Betaxolol  small molecule  ['approved', 'investigational']
# 2  Metoprolol  small molecule  ['approved', 'investigational']
# 3    Atenolol  small molecule                     ['approved']
# 4     Timolol  small molecule                     ['approved']
#
#                                                codes  \
# 0  ['Beta blocking agents, selective', 'BETA BLOC...
# 1  ['Beta blocking agents', 'ANTIGLAUCOMA PREPARA...
# 2  ['Beta blocking agents and calcium channel blo...
# 3  ['Beta blocking agents, selective, and other d...
# 4  ['Beta blocking agents, non-selective', 'BETA ...
#
#                                       smiles  \
# 0        COC(=O)CCC1=CC=C(OCC(O)CNC(C)C)C=C1
# 1        CC(C)NCC(O)COC1=CC=C(CCOCC2CC2)C=C1
# 2             COCCC1=CC=C(OCC(O)CNC(C)C)C=C1
# 3          CC(C)NCC(O)COC1=CC=C(CC(N)=O)C=C1
# 4  [H][C@](O)(CNC(C)(C)C)COC1=NSN=C1N1CCOCC1
#
#                                                atc_4        p_np
# 0                    Beta blocking agents, selective  beta_block
# 1                               Beta blocking agents  beta_block
# 2  Beta blocking agents and calcium channel blockers  beta_block
# 3  Beta blocking agents, selective, and other diu...  beta_block
# 4                Beta blocking agents, non-selective  beta_block

# %%
df_red.shape
# Out:
# (141, 7)

# %%
# Классы получаются весьма малочисленными.

df_red['p_np'].value_counts()
# Out:
# benzodiazepin            39
# beta_block               29
# barbiturat               17
# ca_chan_block_dihidro    17
# ingib_ace                16
# anti_hist                13
# ARBs                     10
# Name: p_np, dtype: int64

# %%
# Заменим названия классов на числовые кодировки.

from sklearn import preprocessing
le = preprocessing.LabelEncoder()

df_red['p_np'] = le.fit_transform(df_red['p_np'])

df_red.head()
# Out:
#      drugname       drug_type                           groups  \
# 0     Esmolol  small molecule        ['approved', 'withdrawn']
# 1   Betaxolol  small molecule  ['approved', 'investigational']
# 2  Metoprolol  small molecule  ['approved', 'investigational']
# 3    Atenolol  small molecule                     ['approved']
# 4     Timolol  small molecule                     ['approved']
#
#                                                codes  \
# 0  ['Beta blocking agents, selective', 'BETA BLOC...
# 1  ['Beta blocking agents', 'ANTIGLAUCOMA PREPARA...
# 2  ['Beta blocking agents and calcium channel blo...
# 3  ['Beta blocking agents, selective, and other d...
# 4  ['Beta blocking agents, non-selective', 'BETA ...
#
#                                       smiles  \
# 0        COC(=O)CCC1=CC=C(OCC(O)CNC(C)C)C=C1
# 1        CC(C)NCC(O)COC1=CC=C(CCOCC2CC2)C=C1
# 2             COCCC1=CC=C(OCC(O)CNC(C)C)C=C1
# 3          CC(C)NCC(O)COC1=CC=C(CC(N)=O)C=C1
# 4  [H][C@](O)(CNC(C)(C)C)COC1=NSN=C1N1CCOCC1
#
#                                                atc_4  p_np
# 0                    Beta blocking agents, selective     4
# 1                               Beta blocking agents     4
# 2  Beta blocking agents and calcium channel blockers     4
# 3  Beta blocking agents, selective, and other diu...     4
# 4                Beta blocking agents, non-selective     4

# %%
df_red['p_np'].value_counts()
# Out:
# 3    39
# 4    29
# 2    17
# 5    17
# 6    16
# 1    13
# 0    10
# Name: p_np, dtype: int64

# %%
# Temporary suppress tf logs
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# Temporary suppress warnings and RDKit logs
warnings.filterwarnings("ignore")
RDLogger.DisableLog("rdApp.*")

np.random.seed(42)
tf.random.set_seed(42)

# %%
# Далее выберем из данных SMILES и целевую переменную p_np.

X = df_red['smiles']
y = df_red['p_np']

# %%
# Сразу разделим и отложим тестовую и валидационную выборки.

x_train, x_test, y_train, y_test = train_test_split(
        X, y,stratify=y, test_size=0.2)

x_test, x_valid, y_test, y_valid = train_test_split(
        x_test, y_test, stratify=y_test, test_size=0.5)

# %%
# Выделим отдельно тренировочный датасет, понадобится для дальнейших преобразований.

train_dataset = pd.DataFrame({'smiles': x_train, 'p_np': y_train})

train_dataset.head()
# Out:
#                                                 smiles  p_np
# 47                     CCCC(C)C1(CC=C)C(=O)NC(=O)NC1=O     2
# 126  CCCCC1=NC(C)=C(CC(=S)N(C)C)C(=O)N1CC1=CC=C(C=C...     0
# 93           ClC1=CC2=C(C=C1)N1C=NN=C1CN=C2C1=CC=CC=C1     3
# 113    OCCN1C2=C(C=C(Cl)C=C2)C(=NC(O)C1=O)C1=CC=CC=C1F     3
# 34   CCOC(=O)[C@H](CCC1=CC=CC=C1)N[C@@H](C)C(=O)N1C...     6

# %% [markdown]
# Так как данные малочисленные, понадобится аугментация.
# Подход к аугментации заимствован из https://arxiv.org/abs/1703.07076, https://github.com/EBjerrum/SMILES-enumeration/blob/master/SmilesEnumerator.py

# %%
class SmilesEnumerator(object):
    """SMILES Enumerator, vectorizer and devectorizer

    #Arguments
        charset: string containing the characters for the vectorization
          can also be generated via the .fit() method
        pad: Length of the vectorization
        leftpad: Add spaces to the left of the SMILES
        isomericSmiles: Generate SMILES containing information about stereogenic centers
        enum: Enumerate the SMILES during transform
        canonical: use canonical SMILES during transform (overrides enum)
    """
    def __init__(self, charset = '@C)(=cOn1S2/H[N]\\', pad=120, leftpad=True, isomericSmiles=True, enum=True, canonical=False):
        self._charset = None
        self.charset = charset
        self.pad = pad
        self.leftpad = leftpad
        self.isomericSmiles = isomericSmiles
        self.enumerate = enum
        self.canonical = canonical

    @property
    def charset(self):
        return self._charset

    @charset.setter
    def charset(self, charset):
        self._charset = charset
        self._charlen = len(charset)
        self._char_to_int = dict((c,i) for i,c in enumerate(charset))
        self._int_to_char = dict((i,c) for i,c in enumerate(charset))

    def fit(self, smiles, extra_chars=[], extra_pad = 5):
        """Performs extraction of the charset and length of a SMILES datasets and sets self.pad and self.charset

        #Arguments
            smiles: Numpy array or Pandas series containing smiles as strings
            extra_chars: List of extra chars to add to the charset (e.g. "\\\\" when "/" is present)
            extra_pad: Extra padding to add before or after the SMILES vectorization
        """
        charset = set("".join(list(smiles)))
        self.charset = "".join(charset.union(set(extra_chars)))
        self.pad = max([len(smile) for smile in smiles]) + extra_pad

    def randomize_smiles(self, smiles):
        """Perform a randomization of a SMILES string
        must be RDKit sanitizable"""
        m = Chem.MolFromSmiles(smiles)
        ans = list(range(m.GetNumAtoms()))
        np.random.shuffle(ans)
        nm = Chem.RenumberAtoms(m,ans)
        return Chem.MolToSmiles(nm, canonical=self.canonical, isomericSmiles=self.isomericSmiles)

    def transform(self, smiles):
        """Perform an enumeration (randomization) and vectorization of a Numpy array of smiles strings
        #Arguments
            smiles: Numpy array or Pandas series containing smiles as strings
        """
        one_hot =  np.zeros((smiles.shape[0], self.pad, self._charlen),dtype=np.int8)

        if self.leftpad:
            for i,ss in enumerate(smiles):
                if self.enumerate: ss = self.randomize_smiles(ss)
                l = len(ss)
                diff = self.pad - l
                for j,c in enumerate(ss):
                    one_hot[i,j+diff,self._char_to_int[c]] = 1
            return one_hot
        else:
            for i,ss in enumerate(smiles):
                if self.enumerate: ss = self.randomize_smiles(ss)
                for j,c in enumerate(ss):
                    one_hot[i,j,self._char_to_int[c]] = 1
            return one_hot


    def reverse_transform(self, vect):
        """ Performs a conversion of a vectorized SMILES to a smiles strings
        charset must be the same as used for vectorization.
        #Arguments
            vect: Numpy array of vectorized SMILES.
        """
        smiles = []
        for v in vect:
            #mask v
            v=v[v.sum(axis=1)==1]
            #Find one hot encoded index with argmax, translate to char and join to string
            smile = "".join(self._int_to_char[i] for i in v.argmax(axis=1))
            smiles.append(smile)
        return np.array(smiles)

# %%
# Функция для аугментации.

def augmentation(dataset, num_classes, augmentation_number):

    sme = SmilesEnumerator()

    df_list = []

    for i in range(num_classes):
        d = dataset[dataset['p_np']==i]

        train_smiles = []

        for smiles in d['smiles']:
            for _ in range(augmentation_number):
                train_smiles.append(sme.randomize_smiles(smiles))

        t_d = pd.DataFrame({'smiles': train_smiles, 'p_np': i})

        exec(f'dataset_{i} = t_d')
        exec(f'df_list.append(dataset_{i})')

    fin_dataset = pd.concat(df_list)

    return (fin_dataset)

# %%
# Выполним аугментацию для тренировочного датасета.
# Каждый класс увеличивается в 15 раз.

train_data = augmentation(train_dataset, 8, 15)

# %%
train_data.shape
# Out:
# (1680, 2)

# %%
# Перемешаем тренировочную выборку.

train_data = train_data.sample(frac=1)

# %%
# Снова разделяем на X и y.

x_train = train_data['smiles']

y_train = train_data['p_np']

# %% [markdown]
# Для реализации MPNN будет использован код из туториала https://keras.io/examples/graph/mpnn-molecular-graphs/

# %%
class Featurizer:
    def __init__(self, allowable_sets):
        self.dim = 0
        self.features_mapping = {}
        for k, s in allowable_sets.items():
            s = sorted(list(s))
            self.features_mapping[k] = dict(zip(s, range(self.dim, len(s) + self.dim)))
            self.dim += len(s)

    def encode(self, inputs):
        output = np.zeros((self.dim,))
        for name_feature, feature_mapping in self.features_mapping.items():
            feature = getattr(self, name_feature)(inputs)
            if feature not in feature_mapping:
                continue
            output[feature_mapping[feature]] = 1.0
        return output


class AtomFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)

    def symbol(self, atom):
        return atom.GetSymbol()

    def n_valence(self, atom):
        return atom.GetTotalValence()

    def n_hydrogens(self, atom):
        return atom.GetTotalNumHs()

    def hybridization(self, atom):
        return atom.GetHybridization().name.lower()


class BondFeaturizer(Featurizer):
    def __init__(self, allowable_sets):
        super().__init__(allowable_sets)
        self.dim += 1

    def encode(self, bond):
        output = np.zeros((self.dim,))
        if bond is None:
            output[-1] = 1.0
            return output
        output = super().encode(bond)
        return output

    def bond_type(self, bond):
        return bond.GetBondType().name.lower()

    def conjugated(self, bond):
        return bond.GetIsConjugated()


atom_featurizer = AtomFeaturizer(
    allowable_sets={
        "symbol": {"B", "Br", "C", "Ca", "Cl", "F", "H", "I", "N", "Na", "O", "P", "S"},
        "n_valence": {0, 1, 2, 3, 4, 5, 6},
        "n_hydrogens": {0, 1, 2, 3, 4},
        "hybridization": {"s", "sp", "sp2", "sp3"},
    }
)

bond_featurizer = BondFeaturizer(
    allowable_sets={
        "bond_type": {"single", "double", "triple", "aromatic"},
        "conjugated": {True, False},
    }
)

# %%
def molecule_from_smiles(smiles):
    # MolFromSmiles(m, sanitize=True) should be equivalent to
    # MolFromSmiles(m, sanitize=False) -> SanitizeMol(m) -> AssignStereochemistry(m, ...)
    molecule = Chem.MolFromSmiles(smiles, sanitize=False)

    # If sanitization is unsuccessful, catch the error, and try again without
    # the sanitization step that caused the error
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        Chem.SanitizeMol(molecule, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ flag)

    Chem.AssignStereochemistry(molecule, cleanIt=True, force=True)
    return molecule


def graph_from_molecule(molecule):
    # Initialize graph
    atom_features = []
    bond_features = []
    pair_indices = []

    for atom in molecule.GetAtoms():
        atom_features.append(atom_featurizer.encode(atom))

        # Add self-loops
        pair_indices.append([atom.GetIdx(), atom.GetIdx()])
        bond_features.append(bond_featurizer.encode(None))

        for neighbor in atom.GetNeighbors():
            bond = molecule.GetBondBetweenAtoms(atom.GetIdx(), neighbor.GetIdx())
            pair_indices.append([atom.GetIdx(), neighbor.GetIdx()])
            bond_features.append(bond_featurizer.encode(bond))

    return np.array(atom_features), np.array(bond_features), np.array(pair_indices)


def graphs_from_smiles(smiles_list):
    # Initialize graphs
    atom_features_list = []
    bond_features_list = []
    pair_indices_list = []

    for smiles in smiles_list:
        molecule = molecule_from_smiles(smiles)
        atom_features, bond_features, pair_indices = graph_from_molecule(molecule)

        atom_features_list.append(atom_features)
        bond_features_list.append(bond_features)
        pair_indices_list.append(pair_indices)

    # Convert lists to ragged tensors for tf.data.Dataset later on
    return (
        tf.ragged.constant(atom_features_list, dtype=tf.float32),
        tf.ragged.constant(bond_features_list, dtype=tf.float32),
        tf.ragged.constant(pair_indices_list, dtype=tf.int64),
    )

# %%
x_train = graphs_from_smiles(x_train)

x_valid = graphs_from_smiles(x_valid)

x_test = graphs_from_smiles(x_test)

# %%
def prepare_batch(x_batch, y_batch):
    """Merges (sub)graphs of batch into a single global (disconnected) graph
    """

    atom_features, bond_features, pair_indices = x_batch

    # Obtain number of atoms and bonds for each graph (molecule)
    num_atoms = atom_features.row_lengths()
    num_bonds = bond_features.row_lengths()

    # Obtain partition indices (molecule_indicator), which will be used to
    # gather (sub)graphs from global graph in model later on
    molecule_indices = tf.range(len(num_atoms))
    molecule_indicator = tf.repeat(molecule_indices, num_atoms)

    # Merge (sub)graphs into a global (disconnected) graph. Adding 'increment' to
    # 'pair_indices' (and merging ragged tensors) actualizes the global graph
    gather_indices = tf.repeat(molecule_indices[:-1], num_bonds[1:])
    increment = tf.cumsum(num_atoms[:-1])
    increment = tf.pad(tf.gather(increment, gather_indices), [(num_bonds[0], 0)])
    pair_indices = pair_indices.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    pair_indices = pair_indices + increment[:, tf.newaxis]
    atom_features = atom_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()
    bond_features = bond_features.merge_dims(outer_axis=0, inner_axis=1).to_tensor()

    return (atom_features, bond_features, pair_indices, molecule_indicator), y_batch


def MPNNDataset(X, y, batch_size=32, shuffle=False):
    dataset = tf.data.Dataset.from_tensor_slices((X, (y)))
    if shuffle:
        dataset = dataset.shuffle(1024)
    return dataset.batch(batch_size).map(prepare_batch, -1).prefetch(-1)

# %%
class EdgeNetwork(layers.Layer):
    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.bond_dim = input_shape[1][-1]
        self.kernel = self.add_weight(
            shape=(self.bond_dim, self.atom_dim * self.atom_dim),
            initializer="glorot_uniform",
            name="kernel",
        )
        self.bias = self.add_weight(
            shape=(self.atom_dim * self.atom_dim), initializer="zeros", name="bias",
        )
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs

        # Apply linear transformation to bond features
        bond_features = tf.matmul(bond_features, self.kernel) + self.bias

        # Reshape for neighborhood aggregation later
        bond_features = tf.reshape(bond_features, (-1, self.atom_dim, self.atom_dim))

        # Obtain atom features of neighbors
        atom_features_neighbors = tf.gather(atom_features, pair_indices[:, 1])
        atom_features_neighbors = tf.expand_dims(atom_features_neighbors, axis=-1)

        # Apply neighborhood aggregation
        transformed_features = tf.matmul(bond_features, atom_features_neighbors)
        transformed_features = tf.squeeze(transformed_features, axis=-1)
        aggregated_features = tf.math.unsorted_segment_sum(
            transformed_features,
            pair_indices[:, 0],
            num_segments=tf.shape(atom_features)[0],
        )
        return aggregated_features


class MessagePassing(layers.Layer):
    def __init__(self, units, steps=4, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.steps = steps

    def build(self, input_shape):
        self.atom_dim = input_shape[0][-1]
        self.message_step = EdgeNetwork()
        self.pad_length = max(0, self.units - self.atom_dim)
        self.update_step = layers.GRUCell(self.atom_dim + self.pad_length)
        self.built = True

    def call(self, inputs):
        atom_features, bond_features, pair_indices = inputs

        # Pad atom features if number of desired units exceeds atom_features dim.
        # Alternatively, a dense layer could be used here.
        atom_features_updated = tf.pad(atom_features, [(0, 0), (0, self.pad_length)])

        # Perform a number of steps of message passing
        for i in range(self.steps):
            # Aggregate information from neighbors
            atom_features_aggregated = self.message_step(
                [atom_features_updated, bond_features, pair_indices]
            )

            # Update node state via a step of GRU
            atom_features_updated, _ = self.update_step(
                atom_features_aggregated, atom_features_updated
            )
        return atom_features_updated

# %%
class PartitionPadding(layers.Layer):
    def __init__(self, batch_size, **kwargs):
        super().__init__(**kwargs)
        self.batch_size = batch_size

    def call(self, inputs):

        atom_features, molecule_indicator = inputs

        # Obtain subgraphs
        atom_features_partitioned = tf.dynamic_partition(
            atom_features, molecule_indicator, self.batch_size
        )

        # Pad and stack subgraphs
        num_atoms = [tf.shape(f)[0] for f in atom_features_partitioned]
        max_num_atoms = tf.reduce_max(num_atoms)
        atom_features_stacked = tf.stack(
            [
                tf.pad(f, [(0, max_num_atoms - n), (0, 0)])
                for f, n in zip(atom_features_partitioned, num_atoms)
            ],
            axis=0,
        )

        # Remove empty subgraphs (usually for last batch in dataset)
        gather_indices = tf.where(tf.reduce_sum(atom_features_stacked, (1, 2)) != 0)
        gather_indices = tf.squeeze(gather_indices, axis=-1)
        return tf.gather(atom_features_stacked, gather_indices, axis=0)


class TransformerEncoderReadout(layers.Layer):
    def __init__(
        self, num_heads=8, embed_dim=64, dense_dim=512, batch_size=32, **kwargs
    ):
        super().__init__(**kwargs)

        self.partition_padding = PartitionPadding(batch_size)
        self.attention = layers.MultiHeadAttention(num_heads, embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.average_pooling = layers.GlobalAveragePooling1D()

    def call(self, inputs):
        x = self.partition_padding(inputs)
        padding_mask = tf.reduce_any(tf.not_equal(x, 0.0), axis=-1)
        padding_mask = padding_mask[:, tf.newaxis, tf.newaxis, :]
        attention_output = self.attention(x, x, attention_mask=padding_mask)
        proj_input = self.layernorm_1(x + attention_output)
        proj_output = self.layernorm_2(proj_input + self.dense_proj(proj_input))
        return self.average_pooling(proj_output)

# %%
from tensorflow.keras.backend import clear_session

clear_session()

# %%
def MPNNModel(
    atom_dim,
    bond_dim,
    batch_size=64,
    message_units=64,
    message_steps=4,
    num_attention_heads=8,
    dense_units=512,
):

    atom_features = layers.Input((atom_dim), dtype="float32", name="atom_features")
    bond_features = layers.Input((bond_dim), dtype="float32", name="bond_features")
    pair_indices = layers.Input((2), dtype="int32", name="pair_indices")
    molecule_indicator = layers.Input((), dtype="int32", name="molecule_indicator")

    x = MessagePassing(message_units, message_steps)(
        [atom_features, bond_features, pair_indices]
    )

    x = TransformerEncoderReadout(
        num_attention_heads, message_units, dense_units, batch_size
    )([x, molecule_indicator])

    x = layers.Dense(dense_units, activation="relu")(x)
    x = layers.Dense(7, activation="softmax")(x)

    model = keras.Model(
        inputs=[atom_features, bond_features, pair_indices, molecule_indicator],
        outputs=[x],
    )
    return model


mpnn = MPNNModel(
    atom_dim=x_train[0][0][0].shape[0], bond_dim=x_train[1][0][0].shape[0],
)

mpnn.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name='accuracy')],
)

keras.utils.plot_model(mpnn, show_dtype=True, show_shapes=True)

# %%
train_dataset = MPNNDataset(x_train, y_train)
valid_dataset = MPNNDataset(x_valid, y_valid)
test_dataset = MPNNDataset(x_test, y_test)

# %%
history = mpnn.fit(
    train_dataset,
    validation_data=valid_dataset,
    epochs=15,
    verbose=2
)
# Out:
# Epoch 1/15
# 53/53 - 36s - loss: 1.2349 - accuracy: 0.6036 - val_loss: 0.7567 - val_accuracy: 0.6667 - 36s/epoch - 687ms/step
# Epoch 2/15
# 53/53 - 23s - loss: 0.5066 - accuracy: 0.9119 - val_loss: 0.2861 - val_accuracy: 0.9333 - 23s/epoch - 428ms/step
# Epoch 3/15
# 53/53 - 23s - loss: 0.2038 - accuracy: 0.9911 - val_loss: 0.1147 - val_accuracy: 1.0000 - 23s/epoch - 432ms/step
# Epoch 4/15
# 53/53 - 22s - loss: 0.0934 - accuracy: 0.9988 - val_loss: 0.0612 - val_accuracy: 1.0000 - 22s/epoch - 421ms/step
# Epoch 5/15
# 53/53 - 23s - loss: 0.0497 - accuracy: 0.9994 - val_loss: 0.0355 - val_accuracy: 1.0000 - 23s/epoch - 425ms/step
# Epoch 6/15
# 53/53 - 22s - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 1.0000 - 22s/epoch - 421ms/step
# Epoch 7/15
# 53/53 - 22s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 1.0000 - 22s/epoch - 412ms/step
# Epoch 8/15
# 53/53 - 22s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000 - 22s/epoch - 414ms/step
# Epoch 9/15
# 53/53 - 22s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 1.0000 - 22s/epoch - 409ms/step
# Epoch 10/15
# 53/53 - 22s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - 22s/epoch - 412ms/step
# Epoch 11/15
# 53/53 - 20s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000 - 20s/epoch - 385ms/step
# Epoch 12/15
# 53/53 - 23s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000 - 23s/epoch - 435ms/step
# Epoch 13/15
# 53/53 - 23s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000 - 23s/epoch - 437ms/step
# Epoch 14/15
# 53/53 - 25s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000 - 25s/epoch - 480ms/step
# Epoch 15/15
# 53/53 - 23s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000 - 23s/epoch - 442ms/step

# %%
y_pred = mpnn.predict(test_dataset)
y_pred
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([[2.90583790e-04, 2.80199427e-04, 5.66415081e-04, 1.43181023e-05,
#         4.55829024e-04, 5.59016422e-04, 9.97833669e-01],
#        [3.77819844e-04, 1.90241175e-04, 2.99317937e-04, 9.84976232e-01,
#         7.24314232e-05, 1.40225170e-02, 6.12850199e-05],
#        [5.88859657e-05, 1.81838608e-04, 3.56220880e-05, 3.35151781e-05,
#         9.98573780e-01, 8.56305414e-05, 1.03077607e-03],
#        [2.72283301e-04, 1.60088792e-04, 3.02237255e-04, 9.88608241e-01,
#         3.86773972e-05, 1.05715655e-02, 4.69497245e-05],
#        [9.20949853e-04, 7.63514618e-05, 9.96798098e-01, 7.91983839e-05,
#         4.39856303e-05, 5.25966927e-04, 1.55555829e-03],
#        [1.11351212e-04, 1.94762561e-05, 2.52869824e-04, 6.95894647e-04,
#         7.10473454e-04, 9.97368455e-01, 8.41551286e-04],
#        [4.47988219e-04, 2.14227446e-04, 1.51755507e-04, 1.97027228e-04,
#         9.94616508e-01, 1.20302977e-03, 3.16941179e-03],
#        [2.64501632e-05, 1.12843954e-04, 1.97578247e-05, 1.93929754e-05,
#         9.99057829e-01, 4.07622902e-05, 7.23034842e-04],
#        [7.07384467e-01, 3.57066258e-03, 4.33577448e-02, 3.40228295e-03,
#         2.31197523e-03, 1.21559612e-01, 1.18413262e-01],
#        [9.42290761e-04, 1.31184992e-04, 9.92407024e-01, 1.40751014e-04,
#         1.04317252e-04, 1.38633186e-03, 4.88809031e-03],
#        [9.06349160e-05, 8.00563066e-05, 3.18166094e-05, 9.99673843e-01,
#         7.58700207e-06, 1.11491783e-04, 4.53142593e-06],
#        [8.71209253e-04, 9.96672630e-01, 4.13108297e-04, 5.38835360e-04,
#         8.55384977e-04, 1.96383116e-04, 4.52439504e-04],
#        [4.92417275e-05, 5.65886294e-05, 1.57649356e-05, 9.99765098e-01,
#         9.90265926e-06, 1.00196892e-04, 3.24447888e-06],
#        [1.50757562e-03, 9.91015017e-01, 3.12543329e-04, 6.28252374e-03,
#         6.26097666e-04, 1.09692737e-04, 1.46499937e-04]], dtype=float32)

# %%
y_pred = np.argmax(y_pred, axis=1)

y_pred
# Out:
# array([6, 3, 4, 3, 2, 5, 4, 4, 0, 2, 3, 1, 3, 1])

# %%
# Метрики на тестовой выборке.

from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         1
#
#     accuracy                           1.00        14
#    macro avg       1.00      1.00      1.00        14
# weighted avg       1.00      1.00      1.00        14

# %%
y_pred_val = mpnn.predict(valid_dataset)
y_pred_val= np.argmax(y_pred_val, axis=1)
# Out:
# 1/1 [==============================] - 0s 173ms/step

# %%
# Метрики на валидационной выборке.

print(classification_report(y_valid, y_pred_val))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history["loss"], label="loss")
plt.xlabel("Epochs", fontsize=16)
plt.ylabel("loss", fontsize=16)
plt.legend(fontsize=16)

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history["accuracy"], label="train accuracy")
plt.plot(history.history["val_accuracy"], label="valid accuracy")
plt.xlabel("Epochs", fontsize=16)
plt.ylabel("accuracy", fontsize=16)
plt.legend(fontsize=16)

# %%
print("MIN Loss:", min(history.history["loss"]))
print("MAX Accuracy:", max(history.history["accuracy"]))
# Out:
# MIN Loss: 0.0030766790732741356
# MAX Accuracy: 1.0
